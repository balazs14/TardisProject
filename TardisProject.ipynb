# %%
import pandas as pd
df = pd.read_csv('okex/okex-futures_quotes_2025-01-02_HYPE-USDT-250606.csv')
df['ts'] = pd.to_datetime(df.local_timestamp, unit='1us')
df.set_index('ts').ask_price.plot()
df.ask_price.describe()
# Out:
# count    76625.000000
# mean        28.019295
# std          0.609782
# min         26.566000
# 25%         27.399000
# 50%         28.184000
# 75%         28.508000
# max         29.494000
# Name: ask_price, dtype: float64
