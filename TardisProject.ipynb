# %%
import pandas as pd
import TardisProject.lib.pandas_utils as pu
from bs4 import BeautifulSoup

# %%
bs4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 bs4
#
# NameError: name 'bs4' is not defined

# %%
BeautifulSoup
# Out:
# bs4.BeautifulSoup

# %%
tardis_dev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tardis_dev
#
# NameError: name 'tardis_dev' is not defined
