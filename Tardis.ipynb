# %%
import sys
import asyncio
from tardis_client import TardisClient, Channel

# %%
print(sys.path)
# Out:
# ['/my', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/my/TardisProject/.venv/lib/python3.12/site-packages']
